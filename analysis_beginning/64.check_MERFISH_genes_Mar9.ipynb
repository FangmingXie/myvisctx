# %%
import itertools
import numpy as np
import pandas as pd
from scipy.stats import ttest_ind
import anndata

import matplotlib.pyplot as plt
from statsmodels.stats.multitest import multipletests
import seaborn as sns

from scroutines import basicu
# from scroutines import powerplots

# %%
sns.set_context('talk')

# %% [markdown]
# # base line

# %%
f = "../data/cheng21_cell_scrna/organized/P28NR.h5ad"
adata = anndata.read(f, backed='r')
genes = adata.var.index.values
genes
# Out:
# array(['4933401J01Rik', 'Gm26206', 'Xkr4', ..., 'CAAA01064564.1',
#        'Vmn2r122', 'CAAA01147332.1'], dtype=object)

# %%
f = "../results/MERFISH_gene_panel_Version1_March9.csv"
df = pd.read_csv(f)

cnddts = df['gene_name_data'].values
unq, cnts = np.unique(cnddts, return_counts=True)
print(len(cnddts), unq.shape, unq[cnts>1], [g for g in cnddts if g not in genes])

df
# Out:
# 503 (503,) [] []
#     gene_name_vizgen gene_name_data           why included  \
# 0              Matn2          Matn2             L2/3 types
# 1             Egfem1         Egfem1  L2/3 types;NRvsDR_DEG
# 2              Grb14          Grb14             L2/3 types
# 3           Adamts17       Adamts17             L2/3 types
# 4               Ldb2           Ldb2             L2/3 types
# ..               ...            ...                    ...
# 498         Sh3pxd2b       Sh3pxd2b             L2/3 types
# 499           Sertm1         Sertm1             L2/3 types
# 500             Mas1           Mas1             L2/3 types
# 501             Scg3           Scg3             L2/3 types
# 502            Hkdc1          Hkdc1             L2/3 types
#
#                         source Annot0 Annot1    Annot2 Annot3      Annot4  \
# 0                 Cheng22_Cell    NaN  A>C>B  screened    NaN  L2/3 types
# 1    Cheng22_Cell;our analysis    NaN  A>C>B  screened    NaN  L2/3 types
# 2                 Cheng22_Cell    NaN  A>C>B         *    NaN  L2/3 types
# 3                 Cheng22_Cell    NaN  A>C>B         *    NaN  L2/3 types
# 4                 Cheng22_Cell    NaN  A>C>B         *    NaN  L2/3 types
# ..                         ...    ...    ...       ...    ...         ...
# 498               Cheng22_Cell    NaN    NaN       NaN    NaN  L2/3 types
# 499               Cheng22_Cell    NaN    NaN       NaN    NaN  L2/3 types
# 500               Cheng22_Cell    NaN    NaN       NaN    NaN  L2/3 types
# 501               Cheng22_Cell    NaN    NaN       NaN    NaN  L2/3 types
# 502               Cheng22_Cell    NaN    NaN       NaN    NaN  L2/3 types
#
#     ispicked P17on     P14      DR Vizgen targets < 50  Target Regions  \
# 0       True     A      BC       1               False           112.0
# 1       True     A  unsure  unsure               False            56.0
# 2       True     A  unsure       1               False            57.0
# 3       True     A  unsure  unsure                True            46.0
# 4       True     A  unsure  unsure               False            69.0
# ..       ...   ...     ...     ...                 ...             ...
# 498    False     B  unsure  unsure               False           226.0
# 499    False     B  unsure  unsure               False            93.0
# 500    False     B  unsure       3               False            59.0
# 501    False     B  unsure       3               False            74.0
# 502    False     B  unsure       1               False            80.0
#
#      Abundance
# 0     2.465576
# 1     0.973929
# 2    16.487443
# 3     0.493933
# 4     7.382394
# ..         ...
# 498   1.757504
# 499   4.621483
# 500   2.104614
# 501  55.862967
# 502   1.370674
#
# [503 rows x 16 columns]

# %%
df['source'].str.contains('Zador').sum()
# Out:
# 103

# %%
df['ispicked'].sum()
# Out:
# 122

# %%
(df['Annot4']=='L2/3 types').sum()
# Out:
# 170

# %%
df['P17on'].value_counts()
# Out:
# C    71
# A    64
# B    35
# Name: P17on, dtype: int64

# %% [markdown]
# # summarize

# %%
unq_reasons = np.unique(np.hstack(df['why included'].str.split(';')))
unq_reasons
# Out:
# array(['All cell types', 'Astrocyte_NRvsDR_DEG', 'Astrocytes',
#        'Early on marker', 'IEG', 'L2/3 SSp', 'L2/3 V1', 'L2/3 dynamic',
#        'L2/3 types', 'L2/3/4 types at P14', 'L4 types', 'L4/5 types',
#        'L5 IT types', 'Microglia', 'NRvsDR_DEG', 'OPC',
#        'V1_HVA_Spatial_Gradient'], dtype='<U23')

# %%
breakdown = []
for reason in unq_reasons:
    num = df['why included'].str.contains(reason).sum()
    breakdown.append({'reason': reason, 'num': num})
breakdown = pd.DataFrame(breakdown)
breakdown.sort_values('num', ascending=False)
# Out:
#                      reason  num
# 8                L2/3 types  170
# 0            All cell types  166
# 10                 L4 types   70
# 13                Microglia   56
# 7              L2/3 dynamic   49
# 14               NRvsDR_DEG   45
# 2                Astrocytes   32
# 4                       IEG   22
# 5                  L2/3 SSp   10
# 1      Astrocyte_NRvsDR_DEG    8
# 9       L2/3/4 types at P14    8
# 12              L5 IT types    8
# 3           Early on marker    4
# 11               L4/5 types    4
# 16  V1_HVA_Spatial_Gradient    4
# 6                   L2/3 V1    3
# 15                      OPC    1

# %%
df.groupby(['why included']).size().to_frame('number').sort_values('number', ascending=False)
# Out:
#                                              number
# why included
# All cell types                                  104
# L2/3 types                                       94
# Microglia                                        53
# L4 types                                         52
# Astrocytes                                       27
# L2/3 types;L2/3 dynamic                          19
# L2/3 types;All cell types                        15
# All cell types;L2/3 types                        11
# All cell types;L4 types                          11
# IEG                                              11
# L2/3 types;NRvsDR_DEG                             9
# L2/3 SSp                                          9
# Astrocyte_NRvsDR_DEG                              8
# L5 IT types                                       6
# IEG;NRvsDR_DEG                                    6
# L2/3 types;L2/3/4 types at P14                    6
# All cell types;L2/3 types;L2/3 dynamic            5
# All cell types;NRvsDR_DEG                         4
# L2/3 types;L2/3 dynamic;NRvsDR_DEG                4
# Microglia;L2/3 dynamic                            3
# All cell types;L2/3 dynamic                       3
# Early on marker                                   3
# IEG;L2/3 dynamic                                  3
# L4 types;NRvsDR_DEG                               3
# L2/3 V1                                           3
# V1_HVA_Spatial_Gradient                           2
# L4/5 types                                        2
# All cell types;L2/3 dynamic;NRvsDR_DEG            2
# L2/3 types;All cell types;NRvsDR_DEG              2
# Astrocytes;L2/3 dynamic                           2
# All cell types;L4 types;L2/3 dynamic              2
# Astrocytes;NRvsDR_DEG                             2
# L2/3 types;All cell types;L2/3 dynamic            1
# IEG;L2/3 dynamic;NRvsDR_DEG                       1
# All cell types;L5 IT types                        1
# OPC;NRvsDR_DEG                                    1
# Early on marker;L2/3 dynamic                      1
# L4/5 types;L5 IT types                            1
# All cell types;L4/5 types                         1
# L4 types;L2/3 dynamic                             1
# All cell types;V1_HVA_Spatial_Gradient            1
# All cell types;IEG;NRvsDR_DEG                     1
# L2/3 SSp;NRvsDR_DEG                               1
# L2/3 types;L4 types                               1
# L2/3 types;L2/3/4 types at P14;L2/3 dynamic       1
# All cell types;L2/3/4 types at P14                1
# All cell types;L2/3 types;NRvsDR_DEG              1
# L2/3 types;Astrocytes                             1
# V1_HVA_Spatial_Gradient;L2/3 dynamic              1

# %%
pd.set_option('display.max_rows', 100)
df.groupby(['why included', 'source']).size().to_frame('number')
# Out:
#                                                                                                 number
# why included                                source
# All cell types                              Chen22_biorxiv_Zador                                    40
#                                             Chen22_biorxiv_Zador;Cheng22_Cell                       11
#                                             Chen22_biorxiv_Zador;our analysis                        5
#                                             Cheng22_Cell                                            48
# All cell types;IEG;NRvsDR_DEG               Chen22_biorxiv_Zador;Hrvatin17_NatNeuro;our ana...       1
# All cell types;L2/3 dynamic                 Chen22_biorxiv_Zador;Cheng22_Cell;our analysis           2
#                                             Cheng22_Cell;our analysis                                1
# All cell types;L2/3 dynamic;NRvsDR_DEG      Chen22_biorxiv_Zador;our analysis                        1
#                                             Cheng22_Cell;our analysis                                1
# All cell types;L2/3 types                   Chen22_biorxiv_Zador;Cheng22_Cell                       11
# All cell types;L2/3 types;L2/3 dynamic      Chen22_biorxiv_Zador;Cheng22_Cell;our analysis           5
# All cell types;L2/3 types;NRvsDR_DEG        Chen22_biorxiv_Zador;Cheng22_Cell;our analysis           1
# All cell types;L2/3/4 types at P14          Chen22_biorxiv_Zador;our analysis                        1
# All cell types;L4 types                     Chen22_biorxiv_Zador;Cheng22_Cell                       11
# All cell types;L4 types;L2/3 dynamic        Chen22_biorxiv_Zador;Cheng22_Cell;our analysis           2
# All cell types;L4/5 types                   Chen22_biorxiv_Zador;Hrvatin17_NatNeuro                  1
# All cell types;L5 IT types                  Cheng22_Cell;Tasic18_Nature                              1
# All cell types;NRvsDR_DEG                   Chen22_biorxiv_Zador;Cheng22_Cell;our analysis           1
#                                             Chen22_biorxiv_Zador;our analysis                        2
#                                             Cheng22_Cell;our analysis                                1
# All cell types;V1_HVA_Spatial_Gradient      Chen22_biorxiv_Zador;Chou13_Science                      1
# Astrocyte_NRvsDR_DEG                        Cheng22_Cell                                             7
#                                             Cheng22_Cell;our analysis                                1
# Astrocytes                                  Bayraktar20_NatNeuro                                    27
# Astrocytes;L2/3 dynamic                     Bayraktar20_NatNeuro;our analysis                        2
# Astrocytes;NRvsDR_DEG                       Bayraktar20_NatNeuro;our analysis                        2
# Early on marker                             Cheng22_Cell                                             3
# Early on marker;L2/3 dynamic                Cheng22_Cell;our analysis                                1
# IEG                                         Hrvatin17_NatNeuro                                      11
# IEG;L2/3 dynamic                            Hrvatin17_NatNeuro;our analysis                          3
# IEG;L2/3 dynamic;NRvsDR_DEG                 Hrvatin17_NatNeuro;our analysis                          1
# IEG;NRvsDR_DEG                              Hrvatin17_NatNeuro;our analysis                          6
# L2/3 SSp                                    Condylis22_Science                                       9
# L2/3 SSp;NRvsDR_DEG                         Condylis22_Science;our analysis                          1
# L2/3 V1                                     Berg21_Nature                                            3
# L2/3 types                                  Cheng22_Cell                                            94
# L2/3 types;All cell types                   Cheng22_Cell;Chen22_biorxiv_Zador                        4
#                                             Cheng22_Cell;Chen22_biorxiv_Zador;our analysis           2
#                                             Cheng22_Cell;our analysis                                9
# L2/3 types;All cell types;L2/3 dynamic      Cheng22_Cell;our analysis                                1
# L2/3 types;All cell types;NRvsDR_DEG        Cheng22_Cell;Chen22_biorxiv_Zador;our analysis           1
#                                             Cheng22_Cell;our analysis                                1
# L2/3 types;Astrocytes                       Cheng22_Cell;Bayraktar20_NatNeuro                        1
# L2/3 types;L2/3 dynamic                     Cheng22_Cell;our analysis                               19
# L2/3 types;L2/3 dynamic;NRvsDR_DEG          Cheng22_Cell;our analysis                                4
# L2/3 types;L2/3/4 types at P14              Cheng22_Cell;our analysis                                6
# L2/3 types;L2/3/4 types at P14;L2/3 dynamic Cheng22_Cell;our analysis                                1
# L2/3 types;L4 types                         Cheng22_Cell;Cheng22_Cell                                1
# L2/3 types;NRvsDR_DEG                       Cheng22_Cell;our analysis                                9
# L4 types                                    Cheng22_Cell                                            51
#                                             Cheng22_Cell;Hrvatin17_NatNeuro                          1
# L4 types;L2/3 dynamic                       Cheng22_Cell;our analysis                                1
# L4 types;NRvsDR_DEG                         Cheng22_Cell;our analysis                                3
# L4/5 types                                  Hrvatin17_NatNeuro                                       2
# L4/5 types;L5 IT types                      Hrvatin17_NatNeuro;Tasic18_Nature                        1
# L5 IT types                                 Tasic18_Nature                                           6
# Microglia                                   Not sure - functionally tested                           5
#                                             Stogsdill22_Nature_ArlottaLab                           48
# Microglia;L2/3 dynamic                      Stogsdill22_Nature_ArlottaLab;our analysis               3
# OPC;NRvsDR_DEG                              Buchanan22_PNAS_Allen;our analysis                       1
# V1_HVA_Spatial_Gradient                     Chou13_Science                                           2
# V1_HVA_Spatial_Gradient;L2/3 dynamic        Chou13_Science;Hrvatin17_NatNeuro;our analysis           1

# %%
df.groupby(['why included']).size().to_frame('number')
# Out:
#                                              number
# why included
# All cell types                                  104
# All cell types;IEG;NRvsDR_DEG                     1
# All cell types;L2/3 dynamic                       3
# All cell types;L2/3 dynamic;NRvsDR_DEG            2
# All cell types;L2/3 types                        11
# All cell types;L2/3 types;L2/3 dynamic            5
# All cell types;L2/3 types;NRvsDR_DEG              1
# All cell types;L2/3/4 types at P14                1
# All cell types;L4 types                          11
# All cell types;L4 types;L2/3 dynamic              2
# All cell types;L4/5 types                         1
# All cell types;L5 IT types                        1
# All cell types;NRvsDR_DEG                         4
# All cell types;V1_HVA_Spatial_Gradient            1
# Astrocyte_NRvsDR_DEG                              8
# Astrocytes                                       27
# Astrocytes;L2/3 dynamic                           2
# Astrocytes;NRvsDR_DEG                             2
# Early on marker                                   3
# Early on marker;L2/3 dynamic                      1
# IEG                                              11
# IEG;L2/3 dynamic                                  3
# IEG;L2/3 dynamic;NRvsDR_DEG                       1
# IEG;NRvsDR_DEG                                    6
# L2/3 SSp                                          9
# L2/3 SSp;NRvsDR_DEG                               1
# L2/3 V1                                           3
# L2/3 types                                       94
# L2/3 types;All cell types                        15
# L2/3 types;All cell types;L2/3 dynamic            1
# L2/3 types;All cell types;NRvsDR_DEG              2
# L2/3 types;Astrocytes                             1
# L2/3 types;L2/3 dynamic                          19
# L2/3 types;L2/3 dynamic;NRvsDR_DEG                4
# L2/3 types;L2/3/4 types at P14                    6
# L2/3 types;L2/3/4 types at P14;L2/3 dynamic       1
# L2/3 types;L4 types                               1
# L2/3 types;NRvsDR_DEG                             9
# L4 types                                         52
# L4 types;L2/3 dynamic                             1
# L4 types;NRvsDR_DEG                               3
# L4/5 types                                        2
# L4/5 types;L5 IT types                            1
# L5 IT types                                       6
# Microglia                                        53
# Microglia;L2/3 dynamic                            3
# OPC;NRvsDR_DEG                                    1
# V1_HVA_Spatial_Gradient                           2
# V1_HVA_Spatial_Gradient;L2/3 dynamic              1

# %%
df.groupby(['why included']).size().sort_values(ascending=False).to_frame('number')
# Out:
#                                              number
# why included
# All cell types                                  104
# L2/3 types                                       94
# Microglia                                        53
# L4 types                                         52
# Astrocytes                                       27
# L2/3 types;L2/3 dynamic                          19
# L2/3 types;All cell types                        15
# All cell types;L2/3 types                        11
# All cell types;L4 types                          11
# IEG                                              11
# L2/3 types;NRvsDR_DEG                             9
# L2/3 SSp                                          9
# Astrocyte_NRvsDR_DEG                              8
# L5 IT types                                       6
# IEG;NRvsDR_DEG                                    6
# L2/3 types;L2/3/4 types at P14                    6
# All cell types;L2/3 types;L2/3 dynamic            5
# All cell types;NRvsDR_DEG                         4
# L2/3 types;L2/3 dynamic;NRvsDR_DEG                4
# Microglia;L2/3 dynamic                            3
# All cell types;L2/3 dynamic                       3
# Early on marker                                   3
# IEG;L2/3 dynamic                                  3
# L4 types;NRvsDR_DEG                               3
# L2/3 V1                                           3
# V1_HVA_Spatial_Gradient                           2
# L4/5 types                                        2
# All cell types;L2/3 dynamic;NRvsDR_DEG            2
# L2/3 types;All cell types;NRvsDR_DEG              2
# Astrocytes;L2/3 dynamic                           2
# All cell types;L4 types;L2/3 dynamic              2
# Astrocytes;NRvsDR_DEG                             2
# L2/3 types;All cell types;L2/3 dynamic            1
# IEG;L2/3 dynamic;NRvsDR_DEG                       1
# All cell types;L5 IT types                        1
# OPC;NRvsDR_DEG                                    1
# Early on marker;L2/3 dynamic                      1
# L4/5 types;L5 IT types                            1
# All cell types;L4/5 types                         1
# L4 types;L2/3 dynamic                             1
# All cell types;V1_HVA_Spatial_Gradient            1
# All cell types;IEG;NRvsDR_DEG                     1
# L2/3 SSp;NRvsDR_DEG                               1
# L2/3 types;L4 types                               1
# L2/3 types;L2/3/4 types at P14;L2/3 dynamic       1
# All cell types;L2/3/4 types at P14                1
# All cell types;L2/3 types;NRvsDR_DEG              1
# L2/3 types;Astrocytes                             1
# V1_HVA_Spatial_Gradient;L2/3 dynamic              1

# %%
df.groupby(['source']).size().to_frame('number')
# Out:
#                                                     number
# source
# Bayraktar20_NatNeuro                                    27
# Bayraktar20_NatNeuro;our analysis                        4
# Berg21_Nature                                            3
# Buchanan22_PNAS_Allen;our analysis                       1
# Chen22_biorxiv_Zador                                    40
# Chen22_biorxiv_Zador;Cheng22_Cell                       33
# Chen22_biorxiv_Zador;Cheng22_Cell;our analysis          11
# Chen22_biorxiv_Zador;Chou13_Science                      1
# Chen22_biorxiv_Zador;Hrvatin17_NatNeuro                  1
# Chen22_biorxiv_Zador;Hrvatin17_NatNeuro;our ana...       1
# Chen22_biorxiv_Zador;our analysis                        9
# Cheng22_Cell                                           203
# Cheng22_Cell;Bayraktar20_NatNeuro                        1
# Cheng22_Cell;Chen22_biorxiv_Zador                        4
# Cheng22_Cell;Chen22_biorxiv_Zador;our analysis           3
# Cheng22_Cell;Cheng22_Cell                                1
# Cheng22_Cell;Hrvatin17_NatNeuro                          1
# Cheng22_Cell;Tasic18_Nature                              1
# Cheng22_Cell;our analysis                               59
# Chou13_Science                                           2
# Chou13_Science;Hrvatin17_NatNeuro;our analysis           1
# Condylis22_Science                                       9
# Condylis22_Science;our analysis                          1
# Hrvatin17_NatNeuro                                      13
# Hrvatin17_NatNeuro;Tasic18_Nature                        1
# Hrvatin17_NatNeuro;our analysis                         10
# Not sure - functionally tested                           5
# Stogsdill22_Nature_ArlottaLab                           48
# Stogsdill22_Nature_ArlottaLab;our analysis               3
# Tasic18_Nature                                           6

# %%
cond1 = df['why included'].str.contains("All cell types")
cond2 = df['source'].str.contains("Chen22_biorxiv_Zador")
print(df[cond1].shape)
print(df[cond2].shape)
print(df[cond1 & cond2].shape)
# Out:
# (166, 16)
# (103, 16)
# (103, 16)

# %%
"March3" in df['gene_name_data'].values
# Out:
# False
