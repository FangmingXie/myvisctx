# %%
import numpy as np
import pandas as pd
from scipy.io import mmread
import os
import glob
import anndata
import tqdm
import zarr
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

from dredFISH.Utils import basicu
from dredFISH.Utils import powerplots

# %%
# %%time
pths = [
    "../data_dump/counts/scRNAseq_Cheng2022_Cell_v1ctx/processed/P28_glut_dr.h5ad",
    "../data_dump/counts/scRNAseq_Cheng2022_Cell_v1ctx/processed/P28_gaba_dr.h5ad",
    "../data_dump/counts/scRNAseq_Cheng2022_Cell_v1ctx/processed/P28_non_dr.h5ad",
]
meta = []
for pth in pths:
    meta_ = anndata.read(pth, backed='r').obs
    meta.append(meta_)
    print(meta_.shape)
meta = pd.concat(meta, join='inner')
newnames = ['-'.join(i.split('-')[:3])+'-P28' for i in meta.index.values]
meta.index = newnames
print(meta.shape)
meta = meta[~meta.index.duplicated(keep='first')]
print(meta.shape)
meta
# Out:
# (16379, 12)
# (2175, 10)
# (6263, 11)
# (24817, 10)
# (24816, 10)
# CPU times: user 490 ms, sys: 177 ms, total: 667 ms
# Wall time: 2.35 s
#                                   n_genes  percent_mito  n_counts  Doublet  \
# AAACGAACATCACAGT-1-P28_dr_1a-P28     3720      0.001237   12124.0    False
# AAACGAATCAATCCGA-1-P28_dr_1a-P28     3798      0.001707   10543.0    False
# AAAGAACCATGCGTGC-1-P28_dr_1a-P28     6513      0.002578   25592.0    False
# AAAGAACTCTACGCAA-1-P28_dr_1a-P28     4570      0.002076   13487.0    False
# AAAGGATAGTGCTCGC-1-P28_dr_1a-P28     3478      0.000669   10466.0    False
# ...                                   ...           ...       ...      ...
# GCTGGGTAGCAAACAT-1-P28_dr_3b-P28     1491      0.002014    2977.0    False
# TCAATTCGTTATAGAG-1-P28_dr_3b-P28      784      0.002935    1021.0    False
# AGAACCTGTGATACAA-1-P28_dr_3b-P28     1092      0.001289    1552.0    False
# GATTCGAGTGATACCT-1-P28_dr_3b-P28     1113      0.001309    1528.0    False
# TGGGATTGTGCGACAA-1-P28_dr_3b-P28     2292      0.000798    6265.0    False
#
#                                   Doublet Score batch leiden     sample  \
# AAACGAACATCACAGT-1-P28_dr_1a-P28       0.027677     0   L4_1  P28_dr_1a
# AAACGAATCAATCCGA-1-P28_dr_1a-P28       0.071549     0     11  P28_dr_1a
# AAAGAACCATGCGTGC-1-P28_dr_1a-P28       0.097239     0   L4_1  P28_dr_1a
# AAAGAACTCTACGCAA-1-P28_dr_1a-P28       0.081595     0   L4_1  P28_dr_1a
# AAAGGATAGTGCTCGC-1-P28_dr_1a-P28       0.122757     0      1  P28_dr_1a
# ...                                         ...   ...    ...        ...
# GCTGGGTAGCAAACAT-1-P28_dr_3b-P28       0.011527   P28      1  P28_dr_3b
# TCAATTCGTTATAGAG-1-P28_dr_3b-P28       0.026968   P28      5  P28_dr_3b
# AGAACCTGTGATACAA-1-P28_dr_3b-P28       0.031783   P28      0  P28_dr_3b
# GATTCGAGTGATACCT-1-P28_dr_3b-P28       0.016036   P28      0  P28_dr_3b
# TGGGATTGTGCGACAA-1-P28_dr_3b-P28       0.016036   P28      8  P28_dr_3b
#
#                                     Type Subclass
# AAACGAACATCACAGT-1-P28_dr_1a-P28    L4_1       L4
# AAACGAATCAATCCGA-1-P28_dr_1a-P28    L4_2       L4
# AAAGAACCATGCGTGC-1-P28_dr_1a-P28    L4_1       L4
# AAAGAACTCTACGCAA-1-P28_dr_1a-P28    L4_1       L4
# AAAGGATAGTGCTCGC-1-P28_dr_1a-P28  L2/3_3     L2/3
# ...                                  ...      ...
# GCTGGGTAGCAAACAT-1-P28_dr_3b-P28    OD_B       OD
# TCAATTCGTTATAGAG-1-P28_dr_3b-P28    Endo     Endo
# AGAACCTGTGATACAA-1-P28_dr_3b-P28   Micro    Micro
# GATTCGAGTGATACCT-1-P28_dr_3b-P28   Micro    Micro
# TGGGATTGTGCGACAA-1-P28_dr_3b-P28    OD_C       OD
#
# [24816 rows x 10 columns]

# %%
np.unique(newnames).shape
# Out:
# (24816,)

# %%
suffixes = ['-'.join(i.split('-')[2:]) for i in meta.index.values]
np.unique(suffixes)
# Out:
# array(['P28_dr_1a-P28', 'P28_dr_1b-P28', 'P28_dr_3a-P28', 'P28_dr_3b-P28'],
#       dtype='<U13')

# %%
meta['sample'].unique()
# Out:
# ['P28_dr_1a', 'P28_dr_1b', 'P28_dr_3a', 'P28_dr_3b']
# Categories (4, object): ['P28_dr_1a', 'P28_dr_1b', 'P28_dr_3a', 'P28_dr_3b']

# %%
ddir = '/bigstore/GeneralStorage/fangming/projects/visctx/data_dump/counts/'
pths = [
    os.path.join(ddir, "scRNAseq_Cheng2022_Cell_v1ctx/P28_dr_1_a/filtered_feature_bc_matrix/counts.h5ad"),
    os.path.join(ddir, "scRNAseq_Cheng2022_Cell_v1ctx/P28_dr_1_b/filtered_feature_bc_matrix/counts.h5ad"),
    os.path.join(ddir, "scRNAseq_Cheng2022_Cell_v1ctx/P28_dr_3_a/filtered_feature_bc_matrix/counts.h5ad"),
    os.path.join(ddir, "scRNAseq_Cheng2022_Cell_v1ctx/P28_dr_3_b/filtered_feature_bc_matrix/counts.h5ad"),
]
renames = [
    "-P28_dr_1a-P28",
    "-P28_dr_1b-P28",
    "-P28_dr_3a-P28",
    "-P28_dr_3b-P28",
]

adata = []
for f, rn in zip(pths, renames):
    adata_ = anndata.read(f)
    adata_.obs.index = np.char.add(adata_.obs.index.values.astype(str), rn)
    print(adata_.shape)
    adata.append(adata_)
    
adata = anndata.concat(adata, merge='same')
print(adata.shape)
adata
# Out:
# (12057, 53801)
# (12670, 53801)
# (9278, 53801)
# (9229, 53801)
# (43234, 53801)
# AnnData object with n_obs × n_vars = 43234 × 53801
#     var: 'id', 'name'

# %%
np.unique(adata.obs.index).shape
# Out:
# (43234,)

# %%
adata_.obs
# Out:
# Empty DataFrame
# Columns: []
# Index: [AAACCCAAGATTACCC-1-P28_dr_3b-P28, AAACCCAAGGACCCAA-1-P28_dr_3b-P28, AAACCCAAGGCGCTCT-1-P28_dr_3b-P28, AAACCCAAGTCGTTAC-1-P28_dr_3b-P28, AAACCCACAAGGCCTC-1-P28_dr_3b-P28, AAACCCACAATGTTGC-1-P28_dr_3b-P28, AAACCCACAGTCTGGC-1-P28_dr_3b-P28, AAACGAAAGGATCATA-1-P28_dr_3b-P28, AAACGAAAGGTCACCC-1-P28_dr_3b-P28, AAACGAACAGAACATA-1-P28_dr_3b-P28, AAACGAACATAGGAGC-1-P28_dr_3b-P28, AAACGAAGTACAAAGT-1-P28_dr_3b-P28, AAACGAAGTAGGGAGG-1-P28_dr_3b-P28, AAACGAAGTCCAAATC-1-P28_dr_3b-P28, AAACGAAGTCGTCAGC-1-P28_dr_3b-P28, AAACGAAGTGGCACTC-1-P28_dr_3b-P28, AAACGAAGTGGGTCAA-1-P28_dr_3b-P28, AAACGCTAGCGATTCT-1-P28_dr_3b-P28, AAACGCTAGCTAAGTA-1-P28_dr_3b-P28, AAACGCTCAAGCGCTC-1-P28_dr_3b-P28, AAACGCTCAATACAGA-1-P28_dr_3b-P28, AAACGCTCAGAATGTA-1-P28_dr_3b-P28, AAACGCTGTCATAAAG-1-P28_dr_3b-P28, AAACGCTGTCTTGAGT-1-P28_dr_3b-P28, AAACGCTGTGTGGACA-1-P28_dr_3b-P28, AAACGCTTCCTCAGGG-1-P28_dr_3b-P28, AAACGCTTCGTGGAAG-1-P28_dr_3b-P28, AAACGCTTCGTTCCCA-1-P28_dr_3b-P28, AAAGAACAGAGAGTTT-1-P28_dr_3b-P28, AAAGAACAGGACGGAG-1-P28_dr_3b-P28, AAAGAACCAACGTATC-1-P28_dr_3b-P28, AAAGAACCAATACGAA-1-P28_dr_3b-P28, AAAGAACGTACAATAG-1-P28_dr_3b-P28, AAAGAACGTCGACTGC-1-P28_dr_3b-P28, AAAGAACGTCTTACTT-1-P28_dr_3b-P28, AAAGAACGTGGTCCCA-1-P28_dr_3b-P28, AAAGAACGTTGCGTAT-1-P28_dr_3b-P28, AAAGAACTCTGCAGCG-1-P28_dr_3b-P28, AAAGGATAGGTGTGAC-1-P28_dr_3b-P28, AAAGGATCAAGCGCTC-1-P28_dr_3b-P28, AAAGGATCAGCCTATA-1-P28_dr_3b-P28, AAAGGATCATTGAAAG-1-P28_dr_3b-P28, AAAGGATGTAGCGTTT-1-P28_dr_3b-P28, AAAGGATGTGCCTGCA-1-P28_dr_3b-P28, AAAGGATGTTGTTTGG-1-P28_dr_3b-P28, AAAGGATTCATCGCAA-1-P28_dr_3b-P28, AAAGGATTCTCCCAAC-1-P28_dr_3b-P28, AAAGGGCAGTATGTAG-1-P28_dr_3b-P28, AAAGGGCCACAAAGCG-1-P28_dr_3b-P28, AAAGGGCCAGGGAGAG-1-P28_dr_3b-P28, AAAGGGCCAGTTACCA-1-P28_dr_3b-P28, AAAGGGCGTCAACCAT-1-P28_dr_3b-P28, AAAGGGCGTCCCGCAA-1-P28_dr_3b-P28, AAAGGGCGTCGAACGA-1-P28_dr_3b-P28, AAAGGGCGTTGCGGAA-1-P28_dr_3b-P28, AAAGGGCTCGTGGTAT-1-P28_dr_3b-P28, AAAGGTACAAGATTGA-1-P28_dr_3b-P28, AAAGGTACACGCAAAG-1-P28_dr_3b-P28, AAAGGTACAGTCTTCC-1-P28_dr_3b-P28, AAAGGTACATCCGAGC-1-P28_dr_3b-P28, AAAGGTAGTCCCGCAA-1-P28_dr_3b-P28, AAAGGTAGTCTACAGT-1-P28_dr_3b-P28, AAAGGTAGTTCTATCT-1-P28_dr_3b-P28, AAAGGTATCTCCATAT-1-P28_dr_3b-P28, AAAGGTATCTGACAGT-1-P28_dr_3b-P28, AAAGTCCAGACTTCCA-1-P28_dr_3b-P28, AAAGTCCCAATCAAGA-1-P28_dr_3b-P28, AAAGTCCGTCGGTGAA-1-P28_dr_3b-P28, AAAGTCCGTGGGAGAG-1-P28_dr_3b-P28, AAAGTCCGTTCGGGTC-1-P28_dr_3b-P28, AAAGTCCGTTTACTGG-1-P28_dr_3b-P28, AAAGTCCGTTTCGACA-1-P28_dr_3b-P28, AAAGTGAAGCGCATCC-1-P28_dr_3b-P28, AAAGTGACACGGTAGA-1-P28_dr_3b-P28, AAAGTGATCTTACGGA-1-P28_dr_3b-P28, AAATGGAAGATTGCGG-1-P28_dr_3b-P28, AAATGGAAGCTAGTTC-1-P28_dr_3b-P28, AAATGGAAGCTCGACC-1-P28_dr_3b-P28, AAATGGAAGGAGAATG-1-P28_dr_3b-P28, AAATGGACAACATACC-1-P28_dr_3b-P28, AAATGGACACCAATTG-1-P28_dr_3b-P28, AAATGGACATGTCAGT-1-P28_dr_3b-P28, AAATGGAGTGTGACCC-1-P28_dr_3b-P28, AAATGGAGTGTGTCGC-1-P28_dr_3b-P28, AACAAAGAGATTCGCT-1-P28_dr_3b-P28, AACAAAGAGGTGCTTT-1-P28_dr_3b-P28, AACAAAGAGTGGAATT-1-P28_dr_3b-P28, AACAAAGCAAATGGCG-1-P28_dr_3b-P28, AACAAAGCACAGTACT-1-P28_dr_3b-P28, AACAAAGCACATGGTT-1-P28_dr_3b-P28, AACAAAGCACCCTTAC-1-P28_dr_3b-P28, AACAAAGGTCACTAGT-1-P28_dr_3b-P28, AACAAAGGTCTACATG-1-P28_dr_3b-P28, AACAAAGGTGCTTATG-1-P28_dr_3b-P28, AACAAAGGTTCGAAGG-1-P28_dr_3b-P28, AACAAAGGTTGGGACA-1-P28_dr_3b-P28, AACAAAGTCGTCCTCA-1-P28_dr_3b-P28, AACAAAGTCTGGAGAG-1-P28_dr_3b-P28, AACAACCCACTGAGTT-1-P28_dr_3b-P28, AACAACCCAGACCAGA-1-P28_dr_3b-P28, ...]
#
# [9229 rows x 0 columns]

# %%
cov = np.asarray(adata.X.sum(axis=1)).reshape(-1,)
medcov = np.median(cov)
adata.obs['cov'] = cov
adata.obs['covfactor'] = cov/medcov

# %%
tmp = adata[meta.index].copy()
unq, inv, cnt = np.unique(tmp.var['name'].values, return_counts=True, return_inverse=True)
tmp = tmp[:, cnt[inv] == 1]
tmp.var = tmp.var.set_index('name')
tmp.obs = tmp.obs.join(meta)
# tmp
# Out:
# /home/fangming/anaconda3/envs/routine/lib/python3.10/site-packages/anndata/_core/anndata.py:798: UserWarning:
# AnnData expects .var.index to contain strings, but got values like:
#     ['4933401J01Rik', 'Gm26206', 'Xkr4', 'Gm18956', 'Gm37180']
#
#     Inferred to be: categorical
#
#   value_idx = self._prep_dim_index(value.index, attr)

# %%
tmp.var
# Out:
#                                 id
# name
# 4933401J01Rik   ENSMUSG00000102693
# Gm26206         ENSMUSG00000064842
# Xkr4            ENSMUSG00000051951
# Gm18956         ENSMUSG00000102851
# Gm37180         ENSMUSG00000103377
# ...                            ...
# CAAA01205117.1  ENSMUSG00000094431
# CAAA01098150.1  ENSMUSG00000094621
# CAAA01064564.1  ENSMUSG00000098647
# Vmn2r122        ENSMUSG00000096730
# CAAA01147332.1  ENSMUSG00000095742
#
# [53547 rows x 1 columns]

# %%
tmp.obs
# Out:
#                                       cov  covfactor  n_genes  percent_mito  \
# AAACGAACATCACAGT-1-P28_dr_1a-P28  12132.0   2.069954     3720      0.001237
# AAACGAATCAATCCGA-1-P28_dr_1a-P28  10548.0   1.799693     3798      0.001707
# AAAGAACCATGCGTGC-1-P28_dr_1a-P28  25610.0   4.369562     6513      0.002578
# AAAGAACTCTACGCAA-1-P28_dr_1a-P28  13491.0   2.301826     4570      0.002076
# AAAGGATAGTGCTCGC-1-P28_dr_1a-P28  10468.0   1.786043     3478      0.000669
# ...                                   ...        ...      ...           ...
# GCTGGGTAGCAAACAT-1-P28_dr_3b-P28   2979.0   0.508275     1491      0.002014
# TCAATTCGTTATAGAG-1-P28_dr_3b-P28   1022.0   0.174373      784      0.002935
# AGAACCTGTGATACAA-1-P28_dr_3b-P28   1552.0   0.264801     1092      0.001289
# GATTCGAGTGATACCT-1-P28_dr_3b-P28   1528.0   0.260706     1113      0.001309
# TGGGATTGTGCGACAA-1-P28_dr_3b-P28   6268.0   1.069442     2292      0.000798
#
#                                   n_counts  Doublet  Doublet Score batch  \
# AAACGAACATCACAGT-1-P28_dr_1a-P28   12124.0    False       0.027677     0
# AAACGAATCAATCCGA-1-P28_dr_1a-P28   10543.0    False       0.071549     0
# AAAGAACCATGCGTGC-1-P28_dr_1a-P28   25592.0    False       0.097239     0
# AAAGAACTCTACGCAA-1-P28_dr_1a-P28   13487.0    False       0.081595     0
# AAAGGATAGTGCTCGC-1-P28_dr_1a-P28   10466.0    False       0.122757     0
# ...                                    ...      ...            ...   ...
# GCTGGGTAGCAAACAT-1-P28_dr_3b-P28    2977.0    False       0.011527   P28
# TCAATTCGTTATAGAG-1-P28_dr_3b-P28    1021.0    False       0.026968   P28
# AGAACCTGTGATACAA-1-P28_dr_3b-P28    1552.0    False       0.031783   P28
# GATTCGAGTGATACCT-1-P28_dr_3b-P28    1528.0    False       0.016036   P28
# TGGGATTGTGCGACAA-1-P28_dr_3b-P28    6265.0    False       0.016036   P28
#
#                                  leiden     sample    Type Subclass
# AAACGAACATCACAGT-1-P28_dr_1a-P28   L4_1  P28_dr_1a    L4_1       L4
# AAACGAATCAATCCGA-1-P28_dr_1a-P28     11  P28_dr_1a    L4_2       L4
# AAAGAACCATGCGTGC-1-P28_dr_1a-P28   L4_1  P28_dr_1a    L4_1       L4
# AAAGAACTCTACGCAA-1-P28_dr_1a-P28   L4_1  P28_dr_1a    L4_1       L4
# AAAGGATAGTGCTCGC-1-P28_dr_1a-P28      1  P28_dr_1a  L2/3_3     L2/3
# ...                                 ...        ...     ...      ...
# GCTGGGTAGCAAACAT-1-P28_dr_3b-P28      1  P28_dr_3b    OD_B       OD
# TCAATTCGTTATAGAG-1-P28_dr_3b-P28      5  P28_dr_3b    Endo     Endo
# AGAACCTGTGATACAA-1-P28_dr_3b-P28      0  P28_dr_3b   Micro    Micro
# GATTCGAGTGATACCT-1-P28_dr_3b-P28      0  P28_dr_3b   Micro    Micro
# TGGGATTGTGCGACAA-1-P28_dr_3b-P28      8  P28_dr_3b    OD_C       OD
#
# [24816 rows x 12 columns]

# %%
pth_res = os.path.join(ddir, "P28_dr_allcells_Oct25.h5ad")
tmp.write(pth_res)

# %%
b = anndata.read(pth_res, backed='r')
b
# Out:
# /home/fangming/anaconda3/envs/routine/lib/python3.10/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# AnnData object with n_obs × n_vars = 24816 × 53547 backed at '/bigstore/GeneralStorage/fangming/projects/visctx/data_dump/counts/P28_dr_allcells_Oct25.h5ad'
#     obs: 'cov', 'covfactor', 'n_genes', 'percent_mito', 'n_counts', 'Doublet', 'Doublet Score', 'batch', 'leiden', 'sample', 'Type', 'Subclass'
#     var: 'id'
