# %%
import numpy as np
import pandas as pd
from scipy.io import mmread
import os
import glob
import anndata
import tqdm
import zarr
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

from dredFISH.Utils import basicu
from dredFISH.Utils import powerplots

# %%
# %%time
pths = [
    "../data_dump/counts/scRNAseq_Cheng2022_Cell_v1ctx/processed/P14_glut.h5ad",
    "../data_dump/counts/scRNAseq_Cheng2022_Cell_v1ctx/processed/P14_gaba.h5ad",
    "../data_dump/counts/scRNAseq_Cheng2022_Cell_v1ctx/processed/P14_non.h5ad",
]
meta = []
for pth in pths:
    meta_ = anndata.read(pth, backed='r').obs
    meta.append(meta_)
    print(meta_.shape)
meta = pd.concat(meta, join='inner')
newnames = ['-'.join(i.split('-')[:4]) for i in meta.index.values]
meta.index = newnames
print(meta.shape)
meta = meta[~meta.index.duplicated(keep='first')]
print(meta.shape)
meta
# Out:
# (21220, 16)
# (2844, 12)
# (7708, 11)
# (31772, 11)
# (31772, 11)
# CPU times: user 605 ms, sys: 81 ms, total: 686 ms
# Wall time: 2.2 s
#                               batch  n_genes  percent_mito  n_counts leiden  \
# AAACCCACACGCACCA-1-P14_1a-P14     0     3578      0.000250   11986.0      2
# AAACCCAGTCCTGAAT-1-P14_1a-P14     0     3520      0.000258   11632.0      3
# AAACCCATCGCTCTCA-1-P14_1a-P14     0     2581      0.000122    8164.0      2
# AAACGAACATGCAGGA-1-P14_1a-P14     0     2542      0.000158    6338.0      3
# AAACGAAGTCCTCAGG-1-P14_1a-P14     0     3203      0.000000    9317.0      2
# ...                             ...      ...           ...       ...    ...
# TTTGATCGTAACCAGG-1-P14_2b-P14   P14     2579      0.000178    5614.0      0
# TTTGATCGTTTGAAAG-1-P14_2b-P14   P14     1199      0.000496    2015.0      1
# TTTGGAGGTATGACAA-1-P14_2b-P14   P14      966      0.002183    1374.0      2
# TTTGGTTGTAGAATGT-1-P14_2b-P14   P14     1935      0.000409    4889.0      4
# TTTGGTTTCAGCAATC-1-P14_2b-P14   P14     2186      0.001841    4887.0      0
#
#                                Doublet  Doublet Score       Class_broad  \
# AAACCCACACGCACCA-1-P14_1a-P14    False       0.014984        Excitatory
# AAACCCAGTCCTGAAT-1-P14_1a-P14    False       0.016756        Excitatory
# AAACCCATCGCTCTCA-1-P14_1a-P14    False       0.012550        Excitatory
# AAACGAACATGCAGGA-1-P14_1a-P14    False       0.028730        Excitatory
# AAACGAAGTCCTCAGG-1-P14_1a-P14    False       0.012168        Excitatory
# ...                                ...            ...               ...
# TTTGATCGTAACCAGG-1-P14_2b-P14    False       0.011671        Astrocytes
# TTTGATCGTTTGAAAG-1-P14_2b-P14    False       0.006068              OPCs
# TTTGGAGGTATGACAA-1-P14_2b-P14    False       0.006733         Microglia
# TTTGGTTGTAGAATGT-1-P14_2b-P14    False       0.020958  Oligodendrocytes
# TTTGGTTTCAGCAATC-1-P14_2b-P14    False       0.010025        Astrocytes
#
#                                sample     Type Subclass
# AAACCCACACGCACCA-1-P14_1a-P14  P14_1a   L6CT_B     L6CT
# AAACCCAGTCCTGAAT-1-P14_1a-P14  P14_1a     L4_A       L4
# AAACCCATCGCTCTCA-1-P14_1a-P14  P14_1a   L6CT_B     L6CT
# AAACGAACATGCAGGA-1-P14_1a-P14  P14_1a     L4_A       L4
# AAACGAAGTCCTCAGG-1-P14_1a-P14  P14_1a   L6CT_B     L6CT
# ...                               ...      ...      ...
# TTTGATCGTAACCAGG-1-P14_2b-P14  P14_2b  Astro_A    Astro
# TTTGATCGTTTGAAAG-1-P14_2b-P14  P14_2b    OPC_A      OPC
# TTTGGAGGTATGACAA-1-P14_2b-P14  P14_2b    Micro    Micro
# TTTGGTTGTAGAATGT-1-P14_2b-P14  P14_2b     OD_A       OD
# TTTGGTTTCAGCAATC-1-P14_2b-P14  P14_2b  Astro_A    Astro
#
# [31772 rows x 11 columns]

# %%
suffixes = ['-'.join(i.split('-')[2:]) for i in meta.index.values]
np.unique(suffixes)
# Out:
# array(['P14_1a-P14', 'P14_1b-P14', 'P14_2a-P14', 'P14_2b-P14'],
#       dtype='<U10')

# %%
meta['sample'].unique()
# Out:
# ['P14_1a', 'P14_1b', 'P14_2a', 'P14_2b']
# Categories (4, object): ['P14_1a', 'P14_1b', 'P14_2a', 'P14_2b']

# %%
ddir = '/bigstore/GeneralStorage/fangming/projects/visctx/data_dump/counts/'
pths = [
    os.path.join(ddir, "scRNAseq_Cheng2022_Cell_v1ctx/P14_nr_1_a/filtered_feature_bc_matrix/counts.h5ad"),
    os.path.join(ddir, "scRNAseq_Cheng2022_Cell_v1ctx/P14_nr_1_b/filtered_feature_bc_matrix/counts.h5ad"),
    os.path.join(ddir, "scRNAseq_Cheng2022_Cell_v1ctx/P14_nr_2_a/filtered_feature_bc_matrix/counts.h5ad"),
    os.path.join(ddir, "scRNAseq_Cheng2022_Cell_v1ctx/P14_nr_2_b/filtered_feature_bc_matrix/counts.h5ad"),
]
renames = [
    "-P14_1a-P14",
    "-P14_1b-P14",
    "-P14_2a-P14",
    "-P14_2b-P14",
]

adata = []
for f, rn in zip(pths, renames):
    adata_ = anndata.read(f)
    adata_.obs.index = np.char.add(adata_.obs.index.values.astype(str), rn)
    print(adata_.shape)
    adata.append(adata_)
    
adata = anndata.concat(adata, merge='same')
print(adata.shape)
adata
# Out:
# (12600, 53801)
# (12813, 53801)
# (8140, 53801)
# (7965, 53801)
# (41518, 53801)
# AnnData object with n_obs × n_vars = 41518 × 53801
#     var: 'id', 'name'

# %%
np.unique(adata.obs.index).shape
# Out:
# (41518,)

# %%
adata_.obs
# Out:
# Empty DataFrame
# Columns: []
# Index: [AAACCCAAGAGCACTG-1-P14_2b-P14, AAACCCAAGCGAGAAA-1-P14_2b-P14, AAACCCAAGGCGTTAG-1-P14_2b-P14, AAACCCAAGTCTCTGA-1-P14_2b-P14, AAACCCAAGTTGGCTT-1-P14_2b-P14, AAACCCACACTTGAAC-1-P14_2b-P14, AAACCCACAGTAACGG-1-P14_2b-P14, AAACCCACATCACCAA-1-P14_2b-P14, AAACCCACATGATCTG-1-P14_2b-P14, AAACCCAGTCTGTGTA-1-P14_2b-P14, AAACCCAGTTCAAACC-1-P14_2b-P14, AAACCCATCAAACTGC-1-P14_2b-P14, AAACGAAAGAAGCTGC-1-P14_2b-P14, AAACGAAAGAGTGTTA-1-
GGACATTGTGCA-1-P14_2b-P14, AAATGGAGTATTTCTC-1-P14_2b-P14, AAATGGAGTCTGTAAC-1-P14_2b-P14, AAATGGAGTTCATCTT-1-P14_2b-P14, AAATGGAGTTCTCAGA-1-P14_2b-P14, AAATGGATCTAGTTCT-1-P14_2b-P14, AACAAAGAGCGCATCC-1-P14_2b-P14, AACAAAGAGGGAGGTG-1-P14_2b-P14, AACAAAGCACATTGTG-1-P14_2b-P14, AACAAAGCACCAATTG-1-P14_2b-P14, AACAAAGCAGCGTGAA-1-P14_2b-P14, AACAAAGGTGCGAGTA-1-P14_2b-P14, AACAAAGTCGAGTGGA-1-P14_2b-P14, AACAAAGTCTTGGTCC-1-P14_2b-P14, AACAACCAGCTAGTTC-1-P14_2b-P14, AACAACCAGTCTAACC-1-P14_2b-P14, AACAACCCAGCAGACA-1-P14_2b-P14, AACAACCCATTACTCT-1-P14_2b-P14, AACAACCGTAACACCT-1-P14_2b-P14, AACAACCGTGCCGAAA-1-P14_2b-P14, AACAACCGTGTACATC-1-P14_2b-P14, AACAACCTCCGATAGT-1-P14_2b-P14, AACAACCTCCGCAGTG-1-P14_2b-P14, AACAAGAAGACTACGG-1-P14_2b-P14, AACAAGACAACGCATT-1-P14_2b-P14, AACAAGACAAGACCTT-1-P14_2b-P14, AACAAGACAGCGGATA-1-P14_2b-P14, AACAAGAGTATCAGCT-1-P14_2b-P14, AACAAGAGTCCATACA-1-P14_2b-P14, AACAAGAGTGAGCCAA-1-P14_2b-P14, AACAAGAGTGTGTTTG-1-P14_2b-P14, ...]
#
# [7965 rows x 0 columns]

# %%
cov = np.asarray(adata.X.sum(axis=1)).reshape(-1,)
medcov = np.median(cov)
adata.obs['cov'] = cov
adata.obs['covfactor'] = cov/medcov

# %%
tmp = adata[meta.index].copy()
unq, inv, cnt = np.unique(tmp.var['name'].values, return_counts=True, return_inverse=True)
tmp = tmp[:, cnt[inv] == 1]
tmp.var = tmp.var.set_index('name')
tmp.obs = tmp.obs.join(meta)
# tmp
# Out:
# /home/fangming/anaconda3/envs/routine/lib/python3.10/site-packages/anndata/_core/anndata.py:798: UserWarning:
# AnnData expects .var.index to contain strings, but got values like:
#     ['4933401J01Rik', 'Gm26206', 'Xkr4', 'Gm18956', 'Gm37180']
#
#     Inferred to be: categorical
#
#   value_idx = self._prep_dim_index(value.index, attr)

# %%
tmp.var
# Out:
#                                 id
# name
# 4933401J01Rik   ENSMUSG00000102693
# Gm26206         ENSMUSG00000064842
# Xkr4            ENSMUSG00000051951
# Gm18956         ENSMUSG00000102851
# Gm37180         ENSMUSG00000103377
# ...                            ...
# CAAA01205117.1  ENSMUSG00000094431
# CAAA01098150.1  ENSMUSG00000094621
# CAAA01064564.1  ENSMUSG00000098647
# Vmn2r122        ENSMUSG00000096730
# CAAA01147332.1  ENSMUSG00000095742
#
# [53547 rows x 1 columns]

# %%
tmp.obs
# Out:
#                                    cov  covfactor batch  n_genes  \
# AAACCCACACGCACCA-1-P14_1a-P14  11986.0   1.360345     0     3578
# AAACGAACATGCAGGA-1-P14_1a-P14     L4_A       L4
# AAACGAAGTCCTCAGG-1-P14_1a-P14   L6CT_B     L6CT
# ...                                ...      ...
# TTTGATCGTAACCAGG-1-P14_2b-P14  Astro_A    Astro
# TTTGATCGTTTGAAAG-1-P14_2b-P14    OPC_A      OPC
# TTTGGAGGTATGACAA-1-P14_2b-P14    Micro    Micro
# TTTGGTTGTAGAATGT-1-P14_2b-P14     OD_A       OD
# TTTGGTTTCAGCAATC-1-P14_2b-P14  Astro_A    Astro
#
# [31772 rows x 13 columns]

# %%
pth_res = os.path.join(ddir, "P14_nr_allcells_Oct26.h5ad")
tmp.write(pth_res)

# %%
b = anndata.read(pth_res, backed='r')
b
# Out:
# /home/fangming/anaconda3/envs/routine/lib/python3.10/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# AnnData object with n_obs × n_vars = 31772 × 53547 backed at '/bigstore/GeneralStorage/fangming/projects/visctx/data_dump/counts/P14_nr_allcells_Oct26.h5ad'
#     obs: 'cov', 'covfactor', 'batch', 'n_genes', 'percent_mito', 'n_counts', 'leiden', 'Doublet', 'Doublet Score', 'Class_broad', 'sample', 'Type', 'Subclass'
#     var: 'id'

# %% [markdown]
# # subselect L234 only

# %%
tmp.shape, meta.shape
# Out:
# ((31772, 53547), (31772, 11))

# %%
np.unique(meta.Type)
# Out:
# array(['Astro_A', 'Astro_B', 'Endo', 'Frem1', 'L2/3_AB', 'L2/3_BC',
#        'L4_A', 'L4_B', 'L4_C', 'L5IT', 'L5NP', 'L5PT_A', 'L5PT_B',
#        'L6CT_A', 'L6CT_B', 'L6CT_C', 'L6IT_A', 'L6IT_B', 'L6b', 'Lamp5',
#        'Micro', 'OD_A', 'OD_B', 'OPC_A', 'OPC_B', 'Pvalb_A', 'Pvalb_B',
#        'Pvalb_C', 'Pvalb_D', 'Sst_A', 'Sst_B', 'Sst_C', 'Sst_D', 'Sst_E',
#        'Stac', 'VLMC_A', 'VLMC_B', 'Vip_A', 'Vip_B', 'Vip_C'],
#       dtype=object)

# %%
selected_types = ['L2/3_AB', 'L2/3_BC', 'L4_A', 'L4_B', 'L4_C']

# %%
tmp_sub = tmp[meta[meta['Type'].isin(selected_types)].index,:]
tmp_sub
# Out:
# View of AnnData object with n_obs × n_vars = 12157 × 53547
#     obs: 'cov', 'covfactor', 'batch', 'n_genes', 'percent_mito', 'n_counts', 'leiden', 'Doublet', 'Doublet Score', 'Class_broad', 'sample', 'Type', 'Subclass'
#     var: 'id'

# %%
pth_res2 = os.path.join(ddir, "P14_nr_L234_Oct26.h5ad")
tmp_sub.write(pth_res2)

# %%
b = anndata.read(pth_res2, backed='r')
b
# Out:
# /home/fangming/anaconda3/envs/routine/lib/python3.10/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# AnnData object with n_obs × n_vars = 12157 × 53547 backed at '/bigstore/GeneralStorage/fangming/projects/visctx/data_dump/counts/P14_nr_L234_Oct26.h5ad'
#     obs: 'cov', 'covfactor', 'batch', 'n_genes', 'percent_mito', 'n_counts', 'leiden', 'Doublet', 'Doublet Score', 'Class_broad', 'sample', 'Type', 'Subclass'
#     var: 'id'
