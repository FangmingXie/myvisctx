# %%
import pandas as pd

# %%
f = './test_erna_data/mm10.gtf.gz'
df = pd.read_csv(f, sep='\t', skiprows=5, header=None,
                 # nrows=100,
                )
df
# Out:
#             0        1           2        3        4  5  6  7  \
# 0        chr1   HAVANA        gene  3073253  3074322  .  +  .
# 1        chr1   HAVANA  transcript  3073253  3074322  .  +  .
# 2        chr1   HAVANA        exon  3073253  3074322  .  +  .
# 3        chr1  ENSEMBL        gene  3102016  3102125  .  +  .
# 4        chr1  ENSEMBL  transcript  3102016  3102125  .  +  .
# ...       ...      ...         ...      ...      ... .. .. ..
# 1872047  chrM  ENSEMBL  transcript    15289    15355  .  +  .
# 1872048  chrM  ENSEMBL        exon    15289    15355  .  +  .
# 1872049  chrM  ENSEMBL        gene    15356    15422  .  -  .
# 1872050  chrM  ENSEMBL  transcript    15356    15422  .  -  .
# 1872051  chrM  ENSEMBL        exon    15356    15422  .  -  .
#
#                                                          8
# 0        gene_id "ENSMUSG00000102693.1"; gene_type "TEC...
# 1        gene_id "ENSMUSG00000102693.1"; transcript_id ...
# ...

# %%
df[2].unique()
# Out:
# array(['gene', 'transcript', 'exon', 'CDS', 'start_codon', 'stop_codon',
#        'UTR', 'Selenocysteine'], dtype=object)

# %%
dfg = df[df[2]=='gene']
dfg
# Out:
#             0        1     2        3        4  5  6  7  \
# 0        chr1   HAVANA  gene  3073253  3074322  .  +  .
# 3        chr1  ENSEMBL  gene  3102016  3102125  .  +  .
# 6        chr1   HAVANA  gene  3205901  3671498  .  -  .
# 24       chr1   HAVANA  gene  3252757  3253236  .  +  .
# 27       chr1   HAVANA  gene  3365731  3368549  .  -  .
# ...       ...      ...   ...      ...      ... .. .. ..
# 1872031  chrM  ENSEMBL  gene    13552    14070  .  -  .
# 1872038  chrM  ENSEMBL  gene    14071    14139  .  -  .
# 1872041  chrM  ENSEMBL  gene    14145    15288  .  +  .
# 1872046  chrM  ENSEMBL  gene    15289    15355  .  +  .
# 1872049  chrM  ENSEMBL  gene    15356    15422  .  -  .
#
#                                                          8
# 0        gene_id "ENSMUSG00000102693.1"; gene_type "TEC...
# 3        gene_id "ENSMUSG00000064842.1"; gene_type "snR...
# 6        gene_id "ENSMUSG00000051951.5"; gene_type "pro...
# ...

# %%
dfg['type'] = dfg[8].apply(lambda x: x.split(';')[1].split(' ')[2].strip('"'))
dfg['type'].value_counts()
# Out:
# /tmp/ipykernel_161356/1496326092.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfg['type'] = dfg[8].apply(lambda x: x.split(';')[1].split(' ')[2].strip('"'))
# protein_coding                        21859
# processed_pseudogene                  10002
# lincRNA                                5629
# TEC                                    3238
# antisense                              2991
# unprocessed_pseudogene                 2723
# miRNA                                  2202
# snoRNA                                 1507
# snRNA                                  1383
# processed_transcript                    779
# misc_RNA                                562
# rRNA                                    354
# ...

# %%
# bed = dfg[[0,3,4]]
# bed.to_csv('./test_erna_data/allgenebodies.bed', header=False, index=False, sep='\t')
