# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import seaborn as sns
from dredFISH.Utils import __init__plots

# %%
fig, ax = plt.subplots(figsize=(6, 1))
fig.subplots_adjust(bottom=0.5)

cmap = matplotlib.cm.jet
norm = matplotlib.colors.BoundaryNorm(np.arange(12)+1, cmap.N, extend='both')
dismap = matplotlib.cm.ScalarMappable(norm=norm, cmap=cmap)

fig.colorbar(dismap,
             cax=ax, orientation='horizontal',
             label="Discrete intervals with extend='both' keyword")
# plt.show()
# Out:
# /tmp/ipykernel_116690/4276196882.py:8: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   fig.colorbar(dismap,

# %%
a = matplotlib.cm.ScalarMappable(norm=norm, cmap=cmap)
a

# %%
palette = {i: a.to_rgba(i)[:3] for i in range(12)}
palette
# Out:
# {0: (0.0, 0.0, 0.5),
#  1: (0.0, 0.0, 0.874331550802139),
#  2: (0.0, 0.1588235294117647, 1.0),
#  3: (0.0, 0.48823529411764705, 1.0),
#  4: (0.0, 0.8333333333333334, 1.0),
#  5: (0.21189120809614148, 1.0, 0.7558507273877295),
#  6: (0.47754585705249836, 1.0, 0.4901960784313726),
#  7: (0.7432005060088547, 1.0, 0.2245414294750162),
#  8: (1.0, 0.9012345679012348, 0.0),
#  9: (1.0, 0.5962236746550474, 0.0),
#  10: (1.0, 0.2912127814088604, 0.0),
#  11: (0.8921568627450983, 0.0, 0.0)}

# %%
plt.scatter(np.arange(12), [0]*12, c=[palette[p] for p in palette.keys()])
