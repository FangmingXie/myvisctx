# %%
import numpy as np
import pandas as pd
from scipy.io import mmread
import os
import glob
import anndata
import tqdm
import zarr
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

from dredFISH.Utils import basicu
from dredFISH.Utils import powerplots

# %%
# %%time
pths = [
    "../data_dump/counts/scRNAseq_Cheng2022_Cell_v1ctx/processed/P28_glut.h5ad",
    "../data_dump/counts/scRNAseq_Cheng2022_Cell_v1ctx/processed/P28_gaba.h5ad",
    "../data_dump/counts/scRNAseq_Cheng2022_Cell_v1ctx/processed/P28_non.h5ad",
]
meta = []
for pth in pths:
    meta_ = anndata.read(pth, backed='r').obs
    meta.append(meta_)
    print(meta_.shape)
meta = pd.concat(meta, join='inner')
meta.index = [i[:-len('-P28-4')] if i.endswith('-P28-4') else i for i in meta.index.values] # fix gaba bug
print(meta.shape)
meta
# Out:
# (15315, 16)
# (2106, 12)
# (6509, 11)
# (23930, 11)
# CPU times: user 536 ms, sys: 517 ms, total: 1.05 s
# Wall time: 1.05 s
#                               batch  n_genes  percent_mito  n_counts leiden  \
# AAACCCACAAATGATG-1-P28_1a-P28   P28     3450      0.000951   10513.0      3
# AAACCCACACCCTAGG-1-P28_1a-P28   P28     4622      0.002900   15174.0      2
# AAACCCAGTTCTCTCG-1-P28_1a-P28   P28     4895      0.002141   16814.0      6
# AAACCCATCACTTGTT-1-P28_1a-P28   P28     3751      0.000471   12745.0      3
# AAACCCATCCTAGCTC-1-P28_1a-P28   P28     4327      0.001903   13661.0      1
# ...                             ...      ...           ...       ...    ...
# TTTGGAGGTTTCCAAG-1-P28_2b-P28   P28     1819      0.002328    3865.0      3
# TTTGGTTCAACACTAC-1-P28_2b-P28   P28     2298      0.000845    5918.0      6
# TTTGGTTGTCCACTTC-1-P28_2b-P28   P28     2419      0.001318    5313.0      2
# TTTGTTGCATAGGTAA-1-P28_2b-P28   P28     1682      0.002540    3541.0      0
# TTTGTTGGTGTCTAAC-1-P28_2b-P28   P28     1151      0.003641    1648.0      1
#
#                                Doublet  Doublet Score       Class_broad  \
# AAACCCACAAATGATG-1-P28_1a-P28    False       0.023377        Excitatory
# AAACCCACACCCTAGG-1-P28_1a-P28    False       0.055276        Excitatory
# AAACCCAGTTCTCTCG-1-P28_1a-P28    False       0.040816        Excitatory
# AAACCCATCACTTGTT-1-P28_1a-P28    False       0.012605        Excitatory
# AAACCCATCCTAGCTC-1-P28_1a-P28    False       0.028505        Excitatory
# ...                                ...            ...               ...
# TTTGGAGGTTTCCAAG-1-P28_2b-P28    False       0.005745  Oligodendrocytes
# TTTGGTTCAACACTAC-1-P28_2b-P28    False       0.008497  Oligodendrocytes
# TTTGGTTGTCCACTTC-1-P28_2b-P28    False       0.009633              OPCs
# TTTGTTGCATAGGTAA-1-P28_2b-P28    False       0.012542        Astrocytes
# TTTGTTGGTGTCTAAC-1-P28_2b-P28    False       0.007420         Microglia
#
#                                sample     Type Subclass
# AAACCCACAAATGATG-1-P28_1a-P28  P28_1a   L6CT_B     L6CT
# AAACCCACACCCTAGG-1-P28_1a-P28  P28_1a     L4_A       L4
# AAACCCAGTTCTCTCG-1-P28_1a-P28  P28_1a   L2/3_C     L2/3
# AAACCCATCACTTGTT-1-P28_1a-P28  P28_1a   L6CT_B     L6CT
# AAACCCATCCTAGCTC-1-P28_1a-P28  P28_1a     L4_B       L4
# ...                               ...      ...      ...
# TTTGGAGGTTTCCAAG-1-P28_2b-P28  P28_2b     OD_B       OD
# TTTGGTTCAACACTAC-1-P28_2b-P28  P28_2b     OD_B       OD
# TTTGGTTGTCCACTTC-1-P28_2b-P28  P28_2b    OPC_A      OPC
# TTTGTTGCATAGGTAA-1-P28_2b-P28  P28_2b  Astro_A    Astro
# TTTGTTGGTGTCTAAC-1-P28_2b-P28  P28_2b    Micro    Micro
#
# [23930 rows x 11 columns]

# %%
meta.loc[[i for i in meta.index if i.endswith('-P28-P28')]]
# Out:
# Empty DataFrame
# Columns: [batch, n_genes, percent_mito, n_counts, leiden, Doublet, Doublet Score, Class_broad, sample, Type, Subclass]
# Index: []

# %%
meta['sample'].unique()
# Out:
# ['P28_1a', 'P28_1b', 'P28_2a', 'P28_2b']
# Categories (4, object): ['P28_1a', 'P28_1b', 'P28_2a', 'P28_2b']

# %%
ddir = '/bigstore/GeneralStorage/fangming/projects/visctx/data_dump/counts/'
pths = [
    os.path.join(ddir, "scRNAseq_Cheng2022_Cell_v1ctx/P28_nr_1_a/filtered_feature_bc_matrix/counts.h5ad"),
    os.path.join(ddir, "scRNAseq_Cheng2022_Cell_v1ctx/P28_nr_1_b/filtered_feature_bc_matrix/counts.h5ad"),
    os.path.join(ddir, "scRNAseq_Cheng2022_Cell_v1ctx/P28_nr_2_a/filtered_feature_bc_matrix/counts.h5ad"),
    os.path.join(ddir, "scRNAseq_Cheng2022_Cell_v1ctx/P28_nr_2_b/filtered_feature_bc_matrix/counts.h5ad"),
]
renames = [
    "-P28_1a-P28",
    "-P28_1b-P28",
    "-P28_2a-P28",
    "-P28_2b-P28",
]

adata = []
for f, rn in zip(pths, renames):
    adata_ = anndata.read(f)
    adata_.obs.index = np.char.add(adata_.obs.index.values.astype(str), rn)
    print(adata_.shape)
    adata.append(adata_)
    
adata = anndata.concat(adata, merge='same')
print(adata.shape)
adata
# Out:
# (6666, 53801)
# (6558, 53801)
# (7268, 53801)
# (7937, 53801)
# (28429, 53801)
# AnnData object with n_obs × n_vars = 28429 × 53801
#     var: 'id', 'name'

# %%
adata_.obs
# Out:
# Empty DataFrame
# Columns: []
# Index: [AAACCCAAGGCTCACC-1-P28_2b-P28, AAACCCACACAAGCCC-1-P28_2b-P28, AAACCCAGTGCCCTTT-1-P28_2b-P28, AAACGAAAGAGGGTCT-1-P28_2b-P28, AAACGAAAGCAGCCTC-1-P28_2b-P28, AAACGAAAGGGTGGGA-1-P28_2b-P28, AAACGAACAAGGATGC-1-P28_2b-P28, AAACGAACACTGTGAT-1-P28_2b-P28, AAACGAAGTGGCCTCA-1-P28_2b-P28, AAACGAATCCCGAGGT-1-P28_2b-P28, AAACGAATCGCCTAGG-1-P28_2b-P28, AAACGAATCTAGATCG-1-P28_2b-P28, AAACGCTAGAGCCGAT-1-P28_2b-P28, AAACGCTAGCATTGTC-1-P28_2b-P28, AAACGCTCAGAGGAAA-1-P28_2b-P28, AAACGCTGTCTGCCTT-1-P28_2b-P28, AAACGCTGTGTTAAAG-1-P28_2b-P28, AAACGCTGTTTACCTT-1-P28_2b-P28, AAACGCTGTTTCACAG-1-P28_2b-P28, AAACGCTTCACTTGTT-1-P28_2b-P28, AAACGCTTCCGACAGC-1-P28_2b-P28, AAACGCTTCGGTAACT-1-P28_2b-P28, AAAGAACCACGGCGTT-1-P28_2b-P28, AAAGAACCAGGCCTGT-1-P28_2b-P28, AAAGAACGTACGGCAA-1-P28_2b-P28, AAAGAACGTGCCGGTT-1-P28_2b-P28, AAAGAACTCAACCTCC-1-P28_2b-P28, AAAGGATAGAGAGTTT-1-P28_2b-P28, AAAGGATAG
28, AACAAAGGTCCTTGTC-1-P28_2b-P28, AACAAAGGTGGTATGG-1-P28_2b-P28, AACAAAGTCACCGACG-1-P28_2b-P28, AACAAAGTCGACGAGA-1-P28_2b-P28, AACAAAGTCGAGCCAC-1-P28_2b-P28, AACAAAGTCTGCAGCG-1-P28_2b-P28, AACAACCAGAATTCAG-1-P28_2b-P28, AACAACCAGCTGTCCG-1-P28_2b-P28, AACAACCCAAATGAAC-1-P28_2b-P28, AACAACCCAAGTCCCG-1-P28_2b-P28, AACAACCCACAACGAG-1-P28_2b-P28, AACAACCCACGCTGCA-1-P28_2b-P28, AACAACCGTCACTCGG-1-P28_2b-P28, AACAACCGTGATACCT-1-P28_2b-P28, ...]
#
# [7937 rows x 0 columns]

# %%
cov = np.asarray(adata.X.sum(axis=1)).reshape(-1,)
medcov = np.median(cov)
adata.obs['cov'] = cov
adata.obs['covfactor'] = cov/medcov

# %%
tmp = adata[meta.index].copy()
unq, inv, cnt = np.unique(tmp.var['name'].values, return_counts=True, return_inverse=True)
tmp = tmp[:, cnt[inv] == 1]
tmp.var = tmp.var.set_index('name')
tmp.obs = tmp.obs.join(meta)
tmp
# Out:
# /home/fangming/anaconda3/envs/routine/lib/python3.10/site-packages/anndata/_core/anndata.py:798: UserWarning:
# AnnData expects .var.index to contain strings, but got values like:
#     ['4933401J01Rik', 'Gm26206', 'Xkr4', 'Gm18956', 'Gm37180']
#
#     Inferred to be: categorical
#
#   value_idx = self._prep_dim_index(value.index, attr)
# AnnData object with n_obs × n_vars = 23930 × 53547
#     obs: 'cov', 'covfactor', 'batch', 'n_genes', 'percent_mito', 'n_counts', 'leiden', 'Doublet', 'Doublet Score', 'Class_broad', 'sample', 'Type', 'Subclass'
#     var: 'id'

# %%
tmp.var
# Out:
#                                 id
# name
# 4933401J01Rik   ENSMUSG00000102693
# Gm26206         ENSMUSG00000064842
# Xkr4            ENSMUSG00000051951
# Gm18956         ENSMUSG00000102851
# Gm37180         ENSMUSG00000103377
# ...                            ...
# CAAA01205117.1  ENSMUSG00000094431
# CAAA01098150.1  ENSMUSG00000094621
# CAAA01064564.1  ENSMUSG00000098647
# Vmn2r122        ENSMUSG00000096730
# CAAA01147332.1  ENSMUSG00000095742
#
# [53547 rows x 1 columns]

# %%
tmp.obs
# Out:
#                                    cov  covfactor batch  n_genes  \
# AAACCCACAAATGATG-1-P28_1a-P28  10513.0   1.043578   P28     3450
# AAACCCACACCCTAGG-1-P28_1a-P28  15174.0   1.506254   P28     4622
# AAACCCAGTTCTCTCG-1-P28_1a-P28  16816.0   1.669248   P28     4895
# AAACCCATCACTTGTT-1-P28_1a-P28  12745.0   1.265138   P28     3751
# AAACCCATCCTAGCTC-1-P28_1a-P28  13661.0   1.356065   P28     4327
# ...                                ...        ...   ...      ...
# TTTGGAGGTTTCCAAG-1-P28_2b-P28   3866.0   0.383760   P28     1819
# TTTGGTTCAACACTAC-1-P28_2b-P28   5919.0   0.587552   P28     2298
# TTTGGTTGTCCACTTC-1-P28_2b-P28   5313.0   0.527397   P28     2419
# TTTGTTGCATAGGTAA-1-P28_2b-P28   3543.0   0.351697   P28     1682
# TTTGTTGGTGTCTAAC-1-P28_2b-P28   1648.0   0.163589   P28     1151
#
#                                percent_mito  n_counts leiden  Doublet  \
# AAACCCACAAATGATG-1-P28_1a-P28      0.000951   10513.0      3    False
# AAACCCACACCCTAGG-1-P28_1a-P28      0.002900   15174.0      2    False
# AAACCCAGTTCTCTCG-1-P28_1a-P28      0.002141   16814.0      6    False
# AAACCCATCACTTGTT-1-P28_1a-P28      0.000471   12745.0      3    False
# AAACCCATCCTAGCTC-1-P28_1a-P28      0.001903   13661.0      1    False
# ...                                     ...       ...    ...      ...
# TTTGGAGGTTTCCAAG-1-P28_2b-P28      0.002328    3865.0      3    False
# TTTGGTTCAACACTAC-1-P28_2b-P28      0.000845    5918.0      6    False
# TTTGGTTGTCCACTTC-1-P28_2b-P28      0.001318    5313.0      2    False
# TTTGTTGCATAGGTAA-1-P28_2b-P28      0.002540    3541.0      0    False
# TTTGTTGGTGTCTAAC-1-P28_2b-P28      0.003641    1648.0      1    False
#
#                                Doublet Score       Class_broad  sample  \
# AAACCCACAAATGATG-1-P28_1a-P28       0.023377        Excitatory  P28_1a
# AAACCCACACCCTAGG-1-P28_1a-P28       0.055276        Excitatory  P28_1a
# AAACCCAGTTCTCTCG-1-P28_1a-P28       0.040816        Excitatory  P28_1a
# AAACCCATCACTTGTT-1-P28_1a-P28       0.012605        Excitatory  P28_1a
# AAACCCATCCTAGCTC-1-P28_1a-P28       0.028505        Excitatory  P28_1a
# ...                                      ...               ...     ...
# TTTGGAGGTTTCCAAG-1-P28_2b-P28       0.005745  Oligodendrocytes  P28_2b
# TTTGGTTCAACACTAC-1-P28_2b-P28       0.008497  Oligodendrocytes  P28_2b
# TTTGGTTGTCCACTTC-1-P28_2b-P28       0.009633              OPCs  P28_2b
# TTTGTTGCATAGGTAA-1-P28_2b-P28       0.012542        Astrocytes  P28_2b
# TTTGTTGGTGTCTAAC-1-P28_2b-P28       0.007420         Microglia  P28_2b
#
#                                   Type Subclass
# AAACCCACAAATGATG-1-P28_1a-P28   L6CT_B     L6CT
# AAACCCACACCCTAGG-1-P28_1a-P28     L4_A       L4
# AAACCCAGTTCTCTCG-1-P28_1a-P28   L2/3_C     L2/3
# AAACCCATCACTTGTT-1-P28_1a-P28   L6CT_B     L6CT
# AAACCCATCCTAGCTC-1-P28_1a-P28     L4_B       L4
# ...                                ...      ...
# TTTGGAGGTTTCCAAG-1-P28_2b-P28     OD_B       OD
# TTTGGTTCAACACTAC-1-P28_2b-P28     OD_B       OD
# TTTGGTTGTCCACTTC-1-P28_2b-P28    OPC_A      OPC
# TTTGTTGCATAGGTAA-1-P28_2b-P28  Astro_A    Astro
# TTTGTTGGTGTCTAAC-1-P28_2b-P28    Micro    Micro
#
# [23930 rows x 13 columns]

# %%
pth_res = os.path.join(ddir, "P28_nr_allcells_Oct24.h5ad")
tmp.write(pth_res)

# %%
b = anndata.read(pth_res, backed='r')
b
# Out:
# /home/fangming/anaconda3/envs/routine/lib/python3.10/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# AnnData object with n_obs × n_vars = 23930 × 53547 backed at '/bigstore/GeneralStorage/fangming/projects/visctx/data_dump/counts/P28_nr_allcells_Oct24.h5ad'
#     obs: 'cov', 'covfactor', 'batch', 'n_genes', 'percent_mito', 'n_counts', 'leiden', 'Doublet', 'Doublet Score', 'Class_broad', 'sample', 'Type', 'Subclass'
#     var: 'id'
